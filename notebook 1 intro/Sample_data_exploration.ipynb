# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### For the detailed information of the respective columns, please check the file pulse2022_data.dictionary_CSV_51 file under the same directory

# %% [markdown]
# # pulse2022_puf_51.csv

# %%
df_pulse2022_puf = pd.read_csv("pulse2022_puf_51.csv")

# %%
df_pulse2022_puf.head()
# Out:
#         SCRAM  WEEK  EST_ST  EST_MSA  REGION      HWEIGHT      PWEIGHT  \
# 0  V510000001    51      34  35620.0       1  1443.711630  5636.201993
# 1  V510000002    51       8      NaN       4   972.449233   952.102570
# 2  V510000003    51      51  47900.0       2   110.034986   211.642852
# 3  V510000004    51      20      NaN       3   752.027703  1385.367189
# 4  V510000005    51       1      NaN       2  1199.873552  2392.803557
#
#    TBIRTH_YEAR  ABIRTH_YEAR  RHISPANIC  ...  FRMLA_TYP4  GAS1  GAS2  GAS3  \
# 0         1973            2          1  ...         -88     1     1   -99
# 1         1945            2          1  ...         -88   -99   -99   -99
# 2         1975            2          1  ...         -88   -99   -99   -99
# 3         1986            2          1  ...         -88     1     1   -99
# 4         1948            2          1  ...         -88   -99   -99   -99
#
#    GAS4  SUMMER_ED1  SUMMER_ED2  SUMMER_ED3  SUMMER_ED4  SUMMER_ED5
# ...

# %%
for ele in df_pulse2022_puf.columns:
    print(ele)
# Out:
# SCRAM
# WEEK
# EST_ST
# EST_MSA
# REGION
# HWEIGHT
# PWEIGHT
# TBIRTH_YEAR
# ABIRTH_YEAR
# RHISPANIC
# AHISPANIC
# RRACE
# ARACE
# EEDUC
# AEDUC
# MS
# EGENID_BIRTH
# AGENID_BIRTH
# GENID_DESCRIBE
# SEXUAL_ORIENTATION
# THHLD_NUMPER
# AHHLD_NUMPER
# THHLD_NUMKID
# AHHLD_NUMKID
# THHLD_NUMADLT
# KIDS_LT5Y
# KIDS_5_11Y
# KIDS_12_17Y
# ENRPUBCHK
# ENRPRVCHK
# ENRHMSCHK
# TENROLLPUB
# TENROLLPRV
# TENROLLHMSCH
# ENROLLNONE
# ACTVDUTY1
# ACTVDUTY2
# ACTVDUTY3
# ACTVDUTY4
# ACTVDUTY5
# RECVDVACC
# NUMDOSES
# BOOSTERRV
# WHYNOBSTR1
# WHYNOBSTR2
# WHYNOBSTR3
# WHYNOBSTR4
# WHYNOBSTR5
# WHYNOBSTR6
# WHYNOBSTR7
# WHYNOBSTR8
# WHYNOBSTR9
# KIDDOSESRV
# KIDDOSESRV_LT5Y
# KIDDOSESRV_5_11Y
# KIDDOSESRV_12_17Y
# KIDBSTR_LT5Y
# KIDBSTR_5_11Y
# KIDBSTR_12_17Y
# KIDGETVAC_LT5Y
# KIDGETVAC_5_11Y
# KIDGETVAC_12_17Y
# KIDWHYNO1
# KIDWHYNO2
# KIDWHYNO3
# KIDWHYNO4
# KIDWHYNO5
# KIDWHYNO6
# KIDWHYNO7
# KIDWHYNO8
# KIDWHYNO9
# KIDWHYNO10
# KIDWHYNO11
# KIDWHYNO12
# KIDWHYNO13
# KIDWHYNO14
# HADCOVIDRV
# ...

# %% [markdown]
# ## Distribution of some selected features

# %%
selected_columns = ['TBIRTH_YEAR','LONGCOVID','RRACE']
for ele in selected_columns:
    c = df_pulse2022_puf[ele]
    plt.figure(figsize=(8,6))
    plt.hist(c, weights=np.ones(len(c)) / len(c)*100,alpha=1)
    plt.xlabel("%s"%(ele), size=14)
    plt.ylabel("Percentage", size=14)
    plt.title("Frequency percentage distribution of %s"%(ele))
    plt.legend(loc='center right')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Pulse2022_repwgt_puf_51.csv
#
# ## This is about the contribution weight of each sampled household

# %%
df_pulse2022_repwgt_puf = pd.read_csv("pulse2022_repwgt_puf_51.csv")

# %%
df_pulse2022_repwgt_puf.head()
# Out:
#         SCRAM  WEEK     HWEIGHT1     HWEIGHT2     HWEIGHT3     HWEIGHT4  \
# 0  V510000001    51  1443.711630   406.184980  2420.003468  1560.973655
# 1  V510000002    51   972.449233  1006.178816   271.316670  1762.732377
# 2  V510000003    51   110.034986   177.004725    35.331906   177.449734
# 3  V510000004    51   752.027703   732.935142   819.572176  1292.622463
# 4  V510000005    51  1199.873552  1497.265157  1106.471389  1052.559366
#
#      HWEIGHT5     HWEIGHT6     HWEIGHT7     HWEIGHT8  ...     PWEIGHT71  \
# 0  394.730018  2495.408178   418.597920  1518.881802  ...  10353.670412
# 1  273.972683   921.301667  1602.707157   307.444911  ...    960.765568
# 2   30.533997   203.617641    31.621444   218.444304  ...    333.543708
# 3  790.617422   233.969321  1152.492785   751.808381  ...   2088.916359
# 4  420.566880  1074.597571  2305.205843  1076.275013  ...   2289.733987
#
#      PWEIGHT72    PWEIGHT73    PWEIGHT74    PWEIGHT75    PWEIGHT76  \
# ...

# %%
for ele in df_pulse2022_repwgt_puf.columns:
    print(ele)
# Out:
# SCRAM
# WEEK
# HWEIGHT1
# HWEIGHT2
# HWEIGHT3
# HWEIGHT4
# HWEIGHT5
# HWEIGHT6
# HWEIGHT7
# HWEIGHT8
# HWEIGHT9
# HWEIGHT10
# HWEIGHT11
# HWEIGHT12
# HWEIGHT13
# HWEIGHT14
# HWEIGHT15
# HWEIGHT16
# HWEIGHT17
# HWEIGHT18
# HWEIGHT19
# HWEIGHT20
# HWEIGHT21
# HWEIGHT22
# HWEIGHT23
# HWEIGHT24
# HWEIGHT25
# HWEIGHT26
# HWEIGHT27
# HWEIGHT28
# HWEIGHT29
# HWEIGHT30
# HWEIGHT31
# HWEIGHT32
# HWEIGHT33
# HWEIGHT34
# HWEIGHT35
# HWEIGHT36
# HWEIGHT37
# HWEIGHT38
# HWEIGHT39
# HWEIGHT40
# HWEIGHT41
# HWEIGHT42
# HWEIGHT43
# HWEIGHT44
# HWEIGHT45
# HWEIGHT46
# HWEIGHT47
# HWEIGHT48
# HWEIGHT49
# HWEIGHT50
# HWEIGHT51
# HWEIGHT52
# HWEIGHT53
# HWEIGHT54
# HWEIGHT55
# HWEIGHT56
# HWEIGHT57
# HWEIGHT58
# HWEIGHT59
# HWEIGHT60
# HWEIGHT61
# HWEIGHT62
# HWEIGHT63
# HWEIGHT64
# HWEIGHT65
# HWEIGHT66
# HWEIGHT67
# HWEIGHT68
# HWEIGHT69
# HWEIGHT70
# HWEIGHT71
# HWEIGHT72
# HWEIGHT73
# HWEIGHT74
# HWEIGHT75
# HWEIGHT76
# HWEIGHT77
# HWEIGHT78
# HWEIGHT79
# HWEIGHT80
# PWEIGHT1
# PWEIGHT2
# PWEIGHT3
# ...

# %% [markdown]
# ### HWEIGHT: Household level weight,The household weight for a particular household is the inverse of its household selection probability multiplied by the inverse of the household response rate in the stratum.
#
# ### PWEIFGHT: Person level weight,The person-level weight for each sampled person in the household is the product of the. final household weight and several weight adjustment factors

# %%
selected_columns = ['HWEIGHT1','PWEIGHT1']
for ele in selected_columns:
    c = df_pulse2022_repwgt_puf[ele]
    bins = np.arange(0,10000,100)
    plt.figure(figsize=(8,6))
    plt.hist(c, bins=bins,weights=np.ones(len(c)) / len(c)*100,alpha=1)
    plt.xlabel("%s"%(ele), size=14)
    plt.ylabel("Percentage", size=14)
    plt.title("Frequency percentage distribution of %s"%(ele))
    plt.legend(loc='center right')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
